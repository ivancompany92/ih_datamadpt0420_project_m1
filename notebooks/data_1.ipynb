# %% [markdown]
# ### Data Acquisition

# %%
# all modules

import pandas as pd
import numpy as np
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///../data/raw/raw_data_project_m1.db')

# %%
query="""
SELECT country_info.country_code,
career_info.normalized_job_code,
personal_info.age
FROM poll_info 
JOIN personal_info 
ON poll_info.uuid = personal_info.uuid 
JOIN career_info 
ON poll_info.uuid = career_info.uuid 
JOIN country_info 
ON poll_info.uuid = country_info.uuid
"""

# %%
df_data_raw = pd.read_sql_query(query, engine)

# %%
df_data_raw.isnull().any()
# Out:
# country_code           False
# normalized_job_code     True
# age                    False
# dtype: bool

# %%
df_data_raw.dropna(inplace=True)
df_data_raw.reset_index(inplace=True)
df_data_raw.drop('index', axis=1,inplace=True)
df_data_raw
# Out:
#      country_code               normalized_job_code           age
# 0              AT  861a9b9151e11362eb3c77ca914172d0  57 years old
# 1              AT  049a3f3a2b5f85cb2971ba77ad66e10c  45 years old
# 2              AT  f4b2fb1aa40f661488e2782b6d57ad2f  41 years old
# 3              AT  27af8700f5577cec835acee2cb90a2ff          1990
# 4              AT  c1b670eba9ccb65e7c99f7da116d5b9c  47 years old
# ...           ...                               ...           ...
# 5697           SK  41b2978a2c07c5f477e60f26372d6c85          2000
# 5698           SK  847165cfda6b1dc82ae22b967da8af2f  37 years old
# 5699           SK  a4d5b8b38f9513825d0d94a981ebe962  53 years old
# 5700           SK  775190277a849cba701b306a7b374c0a  47 years old
# 5701           SK  8a7a3f1bce0958ae9f090683e5a925b7  51 years old
#
# [5702 rows x 3 columns]

# %%
df_data_raw.rename({'country':'Country'}, axis=1, inplace=True)
df_data_raw
# Out:
#      Country               normalized_job_code           age
# 0         AT                              None  61 years old
# 1         AT  861a9b9151e11362eb3c77ca914172d0  57 years old
# 2         AT                              None  32 years old
# 3         AT  049a3f3a2b5f85cb2971ba77ad66e10c  45 years old
# 4         AT  f4b2fb1aa40f661488e2782b6d57ad2f  41 years old
# ...      ...                               ...           ...
# 9644      SK  847165cfda6b1dc82ae22b967da8af2f  37 years old
# 9645      SK  a4d5b8b38f9513825d0d94a981ebe962  53 years old
# 9646      SK                              None          1992
# 9647      SK  775190277a849cba701b306a7b374c0a  47 years old
# 9648      SK  8a7a3f1bce0958ae9f090683e5a925b7  51 years old
#
# [9649 rows x 3 columns]

# %%
country='ES'
df_choice = df_data_raw[df_data_raw['country_code']==f'{country}'].reset_index()

df_choice
# Out:
#       index country_code               normalized_job_code  age
# 0      2212           ES  7028f15ad274cb4d9505101b9c1306b1   59
# 1      2213           ES  a12a16280e22220f9354333f6fe1b22a   41
# 2      2214           ES  e605336f5a43949cb6b18054fd1937f1   52
# 3      2215           ES  0facaffe51cc1998a5fbdbe5fd18fd98   45
# 4      2216           ES  a12a16280e22220f9354333f6fe1b22a   50
# ...     ...          ...                               ...  ...
# 1000   3212           ES                              None   28
# 1001   3213           ES                              None   25
# 1002   3214           ES  dac2e921c1f887d9efc4c06fa33c1397   57
# 1003   3215           ES                              None   52
# 1004   3216           ES                              None   23
#
# [1005 rows x 4 columns]

# %%
df_data_raw.loc[:,:]
# Out:
#      country_code               normalized_job_code           age
# 0              AT                              None  61 years old
# 1              AT  861a9b9151e11362eb3c77ca914172d0  57 years old
# 2              AT                              None  32 years old
# 3              AT  049a3f3a2b5f85cb2971ba77ad66e10c  45 years old
# 4              AT  f4b2fb1aa40f661488e2782b6d57ad2f  41 years old
# ...           ...                               ...           ...
# 9644           SK  847165cfda6b1dc82ae22b967da8af2f  37 years old
# 9645           SK  a4d5b8b38f9513825d0d94a981ebe962  53 years old
# 9646           SK                              None          1992
# 9647           SK  775190277a849cba701b306a7b374c0a  47 years old
# 9648           SK  8a7a3f1bce0958ae9f090683e5a925b7  51 years old
#
# [9649 rows x 3 columns]

# %%
#limpiar años
df_data_raw['age']=df_data_raw['age'].str.replace(r'[a-zA-Z]','')

# %%
df_data_raw['age']=df_data_raw['age'].astype(int)

count=0
for i in df_data_raw['age']:
    if i>1000:
        df_data_raw.loc[count,'age']=2016-i
    count+=1

df_data_raw
# Out:
#      country_code               normalized_job_code  age
# 0              AT                              None   61
# 1              AT  861a9b9151e11362eb3c77ca914172d0   57
# 2              AT                              None   32
# 3              AT  049a3f3a2b5f85cb2971ba77ad66e10c   45
# 4              AT  f4b2fb1aa40f661488e2782b6d57ad2f   41
# ...           ...                               ...  ...
# 9644           SK  847165cfda6b1dc82ae22b967da8af2f   37
# 9645           SK  a4d5b8b38f9513825d0d94a981ebe962   53
# 9646           SK                              None   24
# 9647           SK  775190277a849cba701b306a7b374c0a   47
# 9648           SK  8a7a3f1bce0958ae9f090683e5a925b7   51
#
# [9649 rows x 3 columns]

# %%
jobs_id=df_data_raw['normalized_job_code'].unique()
len(jobs_id)
# Out:
# 157

# %%
import requests

json_complete=[]

for i in jobs_id:
    response = requests.get(f'http://api.dataatwork.org/v1/jobs/{i}')
    json_data = response.json()
    json_complete.append(json_data)

# %%
json_complete[0:5]
# Out:
# [{'error': {'code': 404, 'message': 'Cannot find job with id None'}},
#  {'uuid': '861a9b9151e11362eb3c77ca914172d0',
#   'title': 'Automatic Data Processing Planner',
#   'normalized_job_title': 'automatic data processing planner',
#   'parent_uuid': '0148f61d4227497728ce33490843d056'},
#  {'uuid': '049a3f3a2b5f85cb2971ba77ad66e10c',
#   'title': 'Data Coordinator',
#   'normalized_job_title': 'data coordinator',
#   'parent_uuid': '0b9dd32a367f4562ec77b993053d1910'},
#  {'uuid': 'f4b2fb1aa40f661488e2782b6d57ad2f',
#   'title': 'Database Developer',
#   'normalized_job_title': 'database developer',
#   'parent_uuid': 'b90ca4df5690002377a7b0f1f3d40781'},
#  {'uuid': '27af8700f5577cec835acee2cb90a2ff',
#   'title': 'Data Entry Specialist',
#   'normalized_job_title': 'data entry specialist',
#   'parent_uuid': 'bf88358c56bb6cbe7eabec38ae333d19'}]

# %%
json_complete[1]
# Out:
# {'uuid': '861a9b9151e11362eb3c77ca914172d0',
#  'title': 'Automatic Data Processing Planner',
#  'normalized_job_title': 'automatic data processing planner',
#  'parent_uuid': '0148f61d4227497728ce33490843d056'}

# %%
count=0
for code in df_data_raw['normalized_job_code']:
    for job in json_complete:
        if (job.get('uuid')==code) and (code!=None):
            df_data_raw.loc[count,'normalized_job_code']=job.get('title')
    count+=1

# %%
df_data_raw[0:70]
# Out:
#    country_code                             normalized_job_code  age
# 0            AT                                            None   61
# 1            AT               Automatic Data Processing Planner   57
# 2            AT                                            None   32
# 3            AT                                Data Coordinator   45
# 4            AT                              Database Developer   41
# ..          ...                                             ...  ...
# 65           AT                                            None   47
# 66           AT                                            None   25
# 67           AT  Computer or Data Processing Systems Consultant   65
# 68           AT                                Data Coordinator   46
# 69           AT                                            None   17
#
# [70 rows x 3 columns]

# %%
count=0
for code in df_data_raw['normalized_job_code']:
    if code==None:
        df_data_raw.loc[count,'normalized_job_code']='Jobless'
    count+=1

df_data_raw
# Out:
#      country_code                normalized_job_code  age
# 0              AT                            Jobless   61
# 1              AT  Automatic Data Processing Planner   57
# 2              AT                            Jobless   32
# 3              AT                   Data Coordinator   45
# 4              AT                 Database Developer   41
# ...           ...                                ...  ...
# 9644           SK           Data Warehouse Developer   37
# 9645           SK                   Database Manager   53
# 9646           SK                            Jobless   24
# 9647           SK                       Data Officer   47
# 9648           SK                     Data Scientist   51
#
# [9649 rows x 3 columns]

# %%
import requests
from bs4 import BeautifulSoup
url = 'https://ec.europa.eu/eurostat/statistics-explained/index.php/Glossary:Country_codes'
html = requests.get(url).text
html[:5000]
soup = BeautifulSoup(html, 'lxml')
table = soup.find_all('td')


countries_raw=[]
for i in table:
    countries_raw.append(i.text)

countries_raw[0:5]
# Out:
# ['Belgium\n', '(BE)\n', 'Greece\n', '(EL)\n', 'Lithuania\n']

# %%
#clean countries
import re

countries=[]
for i in countries_raw:
    a=re.sub('\n','',i)
    b=re.sub('^ ','',a)
    try:
        if b[0]=='(':
            b=b[1:3]
    except:
        continue
        
    countries.append(b)

countries[:58]
# Out:
# ['Belgium',
#  'BE',
#  'Greece',
#  'EL',
#  'Lithuania',
#  'LT',
#  'Portugal',
#  'PT',
#  'Bulgaria',
#  'BG',
#  'Spain',
#  'ES',
#  'Luxembourg',
#  'LU',
#  'Romania',
#  'RO',
#  'Czechia',
#  'CZ',
#  'France',
#  'FR',
#  'Hungary',
#  'HU',
#  'Slovenia',
#  'SI',
#  'Denmark',
#  'DK',
#  'Croatia',
#  'HR',
#  'Malta',
#  'MT',
#  'Slovakia',
#  'SK',
#  'Germany',
#  'DE',
#  'Italy',
#  'IT',
#  'Netherlands',
#  'NL',
#  'Finland',
#  'FI',
#  'Estonia',
#  'EE',
#  'Cyprus',
#  'CY',
#  'Austria',
#  'AT',
#  'Sweden',
#  'SE',
#  'Ireland',
#  'IE',
#  'Latvia',
#  'LV',
#  'Poland',
#  'PL',
#  'United Kingdom',
#  'UK',
#  'Iceland',
#  'IS']

# %%
countries_library={}
for i in range(1,57,2):
    countries_library[f'{countries[i]}']=countries[i-1]

countries_library
# Out:
# {'BE': 'Belgium',
#  'EL': 'Greece',
#  'LT': 'Lithuania',
#  'PT': 'Portugal',
#  'BG': 'Bulgaria',
#  'ES': 'Spain',
#  'LU': 'Luxembourg',
#  'RO': 'Romania',
#  'CZ': 'Czechia',
#  'FR': 'France',
#  'HU': 'Hungary',
#  'SI': 'Slovenia',
#  'DK': 'Denmark',
#  'HR': 'Croatia',
#  'MT': 'Malta',
#  'SK': 'Slovakia',
#  'DE': 'Germany',
#  'IT': 'Italy',
#  'NL': 'Netherlands',
#  'FI': 'Finland',
#  'EE': 'Estonia',
#  'CY': 'Cyprus',
#  'AT': 'Austria',
#  'SE': 'Sweden',
#  'IE': 'Ireland',
#  'LV': 'Latvia',
#  'PL': 'Poland',
#  'UK': 'United Kingdom'}

# %%
list(countries_library.values())
# Out:
# ['Belgium',
#  'Greece',
#  'Lithuania',
#  'Portugal',
#  'Bulgaria',
#  'Spain',
#  'Luxembourg',
#  'Romania',
#  'Czechia',
#  'France',
#  'Hungary',
#  'Slovenia',
#  'Denmark',
#  'Croatia',
#  'Malta',
#  'Slovakia',
#  'Germany',
#  'Italy',
#  'Netherlands',
#  'Finland',
#  'Estonia',
#  'Cyprus',
#  'Austria',
#  'Sweden',
#  'Ireland',
#  'Latvia',
#  'Poland',
#  'United Kingdom']

# %%
country = 'spAin'

country=country.lower().capitalize()
if country in list(countries_library.values()):
    print('ok')
# Out:
# ok

# %%
count=0
for i in df_data_raw['country_code']:
    if i=='GB':
        df_data_raw.loc[count,'country_code']='UK'
    elif i=='GR':
        df_data_raw.loc[count,'country_code']='EL'
    count+=1
    
df_data_raw
# Out:
#      country_code                normalized_job_code  age
# 0              AT                            Jobless   61
# 1              AT  Automatic Data Processing Planner   57
# 2              AT                            Jobless   32
# 3              AT                   Data Coordinator   45
# 4              AT                 Database Developer   41
# ...           ...                                ...  ...
# 9644           SK           Data Warehouse Developer   37
# 9645           SK                   Database Manager   53
# 9646           SK                            Jobless   24
# 9647           SK                       Data Officer   47
# 9648           SK                     Data Scientist   51
#
# [9649 rows x 3 columns]

# %%
count=0
for country in df_data_raw['country_code']:
    df_data_raw.loc[count,'country_code']=countries_library[country]
    count+=1

# %%
df_data_raw.head(10)
# Out:
#   country_code                                normalized_job_code  age
# 0      Austria                                            Jobless   61
# 1      Austria                  Automatic Data Processing Planner   57
# 2      Austria                                            Jobless   32
# 3      Austria                                   Data Coordinator   45
# 4      Austria                                 Database Developer   41
# 5      Austria                              Data Entry Specialist   26
# 6      Austria                                            Jobless   26
# 7      Austria                                 Database Architect   47
# 8      Austria  Geographic Information Systems Database Admini...   34
# 9      Austria                                            Jobless   22

# %%
count=0
for i in df_data_raw['age']:
    if i<26:
        df_data_raw.loc[count,'age_group']= '14_25'
    elif i>39:
        df_data_raw.loc[count,'age_group']= '40_65'
    else:
        df_data_raw.loc[count,'age_group']= '26_39'
    count+=1
df_data_raw
# Out:
#      country_code                normalized_job_code  age age_group
# 0         Austria                            Jobless   61     40_65
# 1         Austria  Automatic Data Processing Planner   57     40_65
# 2         Austria                            Jobless   32     26_39
# 3         Austria                   Data Coordinator   45     40_65
# 4         Austria                 Database Developer   41     40_65
# ...           ...                                ...  ...       ...
# 9644     Slovakia           Data Warehouse Developer   37     26_39
# 9645     Slovakia                   Database Manager   53     40_65
# 9646     Slovakia                            Jobless   24     14_25
# 9647     Slovakia                       Data Officer   47     40_65
# 9648     Slovakia                     Data Scientist   51     40_65
#
# [9649 rows x 4 columns]

# %%
df_data_raw
# Out:
#      country_code                normalized_job_code  age age_group
# 0         Austria                            Jobless   61     40_65
# 1         Austria  Automatic Data Processing Planner   57     40_65
# 2         Austria                            Jobless   32     26_39
# 3         Austria                   Data Coordinator   45     40_65
# 4         Austria                 Database Developer   41     40_65
# ...           ...                                ...  ...       ...
# 9644     Slovakia           Data Warehouse Developer   37     26_39
# 9645     Slovakia                   Database Manager   53     40_65
# 9646     Slovakia                            Jobless   24     14_25
# 9647     Slovakia                       Data Officer   47     40_65
# 9648     Slovakia                     Data Scientist   51     40_65
#
# [9649 rows x 4 columns]

# %%
df_hola = df_data_raw[df_data_raw['country_code']=='Spain']
# df_hola=df_hola.drop(['index'],axis=1)
df_hola.reset_index(inplace=True)
df_hola
# Out:
#       index country_code                                normalized_job_code  \
# 0      2212        Spain     Clinical Data Management Manager (CDM Manager)
# 1      2213        Spain  Geographic Information Systems Data Administra...
# 2      2214        Spain                           Database Security Expert
# 3      2215        Spain  Weight in Motion Field Data Collection Technician
# 4      2216        Spain  Geographic Information Systems Data Administra...
# ...     ...          ...                                                ...
# 1000   3212        Spain                                            Jobless
# 1001   3213        Spain                                            Jobless
# 1002   3214        Spain  Automatic Data Processing Customer Liaison (AD...
# 1003   3215        Spain                                            Jobless
# 1004   3216        Spain                                            Jobless
#
#       age age_group
# 0      59     40_65
# 1      41     40_65
# 2      52     40_65
# 3      45     40_65
# 4      50     40_65
# ...   ...       ...
# 1000   28     26_39
# 1001   25     14_25
# 1002   57     40_65
# 1003   52     40_65
# 1004   23     14_25
#
# [1005 rows x 5 columns]

# %%
df_3=df_data_raw.groupby(['country_code','normalized_job_code','age_group']).count()
print(df_3.columns)
# Out:
# Index(['age'], dtype='object')

# %%
df_3.columns=['Quantity']
df_3.reset_index(inplace=True)
df_3
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-b45b2113a7f7> in <module>
# ----> 1 df_3.columns=['Quantity']
#       2 df_3.reset_index(inplace=True)
#       3 df_3
#
# ~/miniconda3/envs/IronHack_env/lib/python3.7/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5285         try:
#    5286             object.__getattribute__(self, name)
# -> 5287             return object.__setattr__(self, name, value)
#    5288         except AttributeError:
#    5289             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~/miniconda3/envs/IronHack_env/lib/python3.7/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     659
#     660     def _set_axis(self, axis, labels) -> None:
# --> 661         self._data.set_axis(axis, labels)
#     662         self._clear_item_cache()
#     663
#
# ~/miniconda3/envs/IronHack_env/lib/python3.7/site-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     176         if new_len != old_len:
#     177             raise ValueError(
# --> 178                 f"Length mismatch: Expected axis has {old_len} elements, new "
#     179                 f"values have {new_len} elements"
#     180             )
#
# ValueError: Length mismatch: Expected axis has 4 elements, new values have 1 elements

# %%
df_4=(df_3[['Quantity']]/df_3[['Quantity']].sum())*100
df_4=df_4.round(2)
df_4
# Out:
#       Quantity
# 0         0.01
# 1         0.01
# 2         0.02
# 3         0.01
# 4         0.01
# ...        ...
# 2949      0.01
# 2950      0.03
# 2951      0.02
# 2952      0.03
# 2953      0.01
#
# [2954 rows x 1 columns]

# %%
# df_1=df_data_raw.groupby(by=['country_code','normalized_job_code','age_group']).agg({'age':'count'})
# df_1.columns=['Count']
# df_1=df_1.reset_index()
# df_1

# %%
df_4.columns=['Percentage']

# %%
df_3
# Out:
#         country_code                                normalized_job_code  \
# 0            Austria  Automatic Data Processing Customer Liaison (AD...
# 1            Austria  Automatic Data Processing Customer Liaison (AD...
# 2            Austria                  Automatic Data Processing Planner
# 3            Austria  Automatic Data Processing Systems Security Spe...
# 4            Austria  Automatic Data Processing Systems Security Spe...
# ...              ...                                                ...
# 2949  United Kingdom  SCADA Technician (Supervisory Control and Data...
# 2950  United Kingdom                         SQL Database Administrator
# 2951  United Kingdom                         SQL Database Administrator
# 2952  United Kingdom                         SQL Database Administrator
# 2953  United Kingdom                             Survey Data Technician
#
#      age_group  Quantity
# 0        26_39         1
# 1        40_65         1
# 2        40_65         2
# 3        26_39         1
# 4        40_65         1
# ...        ...       ...
# 2949     26_39         1
# 2950     14_25         3
# 2951     26_39         2
# 2952     40_65         3
# 2953     26_39         1
#
# [2954 rows x 4 columns]

# %%
df_3[['Quantity']].sum()
# Out:
# Quantity    9649
# dtype: int64

# %%
df_4
# Out:
#       Percentage
# 0           0.01
# 1           0.01
# 2           0.02
# 3           0.01
# 4           0.01
# ...          ...
# 2949        0.01
# 2950        0.03
# 2951        0.02
# 2952        0.03
# 2953        0.01
#
# [2954 rows x 1 columns]

# %%
df_total=pd.merge(df_3, df_4, left_index=True, right_index=True)

df_total[0:70]
# Out:
#    country_code                                normalized_job_code age_group  \
# 0       Austria  Automatic Data Processing Customer Liaison (AD...     26_39
# 1       Austria  Automatic Data Processing Customer Liaison (AD...     40_65
# 2       Austria                  Automatic Data Processing Planner     40_65
# 3       Austria  Automatic Data Processing Systems Security Spe...     26_39
# 4       Austria  Automatic Data Processing Systems Security Spe...     40_65
# ..          ...                                                ...       ...
# 65      Austria                                            Jobless     40_65
# 66      Austria                           Maintenance Data Analyst     40_65
# 67      Austria  Naval Tactical Data System--Combat Information...     14_25
# 68      Austria  Naval Tactical Data System--Combat Information...     26_39
# 69      Belgium  Automatic Data Processing Customer Liaison (AD...     40_65
#
#     Quantity  Percentage
# 0          1        0.01
# 1          1        0.01
# 2          2        0.02
# 3          1        0.01
# 4          1        0.01
# ..       ...         ...
# 65        11        0.11
# 66         1        0.01
# 67         1        0.01
# 68         1        0.01
# 69         1        0.01
#
# [70 rows x 5 columns]
